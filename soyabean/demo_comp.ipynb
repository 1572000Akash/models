# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
soya1= pd.read_csv("Soyabean1.csv")

# %%
soya2= pd.read_csv("newdfsoyabean2019.csv")

# %%
soya1
# Out:
#               State       District Arrival_date  Sold_Amount/tonns Unnamed: 4
# 0       Chattisgarh    Balodabazar          Jan                6.9        NaN
# 1       Chattisgarh           Durg          Jan              958.5        NaN
# 2       Chattisgarh      Kabirdham          Jan              242.4        NaN
# 3       Chattisgarh        Mungeli          Jan              151.9        NaN
# 4       Chattisgarh         Raipur          Jan              630.2        NaN
# 5       Chattisgarh    Rajnandgaon          Jan             2946.9        NaN
# 6       Chattisgarh    Balodabazar          Feb               15.5        NaN
# 7       Chattisgarh           Durg          Feb              599.0        NaN
# 8       Chattisgarh      Kabirdham          Feb              287.3        NaN
# 9       Chattisgarh        Mungeli          Feb               96.5        NaN
# 10      Chattisgarh         Raipur          Feb              312.9        NaN
# ...

# %%
soya2
# Out:
#      arrival_date           state   variety     district  modal_price
# 0             Jan  Madhya Pradesh     Other      Shehdol  3295.833333
# 1             Jan  Madhya Pradesh  Soyabeen   Ashoknagar  3357.142857
# 2             Jan  Madhya Pradesh     Other      Vidisha  3404.130435
# 3             Jan  Madhya Pradesh     Other      Umariya  3440.000000
# 4             Jan  Madhya Pradesh     Other    Tikamgarh  3315.000000
# 5             Jan  Madhya Pradesh     Other     Shivpuri  3522.909091
# 6             Jan  Madhya Pradesh     Other      Sheopur  3472.857143
# 7             Jan  Madhya Pradesh     Other     Shajapur  3572.171171
# 8             Jan  Madhya Pradesh     Other        Seoni  3075.000000
# 9             Jan  Madhya Pradesh     Other       Sehore  3501.000000
# 10            Jan  Madhya Pradesh     Other        Satna  3191.562500
# 11            Jan  Madhya Pradesh     Other        Sagar  3247.500000
# ...

# %%
count = soya2.groupby(['state']).count() 
print(count)
# Out:
#                 arrival_date  variety  district  modal_price
# state
# Chattisgarh              106      106       106          106
# Gujarat                  137      137       137          137
# Karnataka                 86       86        86           86
# Madhya Pradesh          1063     1063      1063         1063
# Maharashtra              476      476       476          476
# Manipur                    4        4         4            4
# Rajasthan                106      106       106          106
# Uttar Pradesh             24       24        24           24

# %%
count1 = soya1.groupby(['State']).count() 
print(count1)
# Out:
#                District  Arrival_date  Sold_Amount/tonns  Unnamed: 4
# State
# Chattisgarh          66            66                 66           0
# Gujarat              99            99                 99           0
# MP                  454           454                454           0
# Manipur              55            55                 55           0
# Uttar Pradesh        22            22                 22           0
# karnataka            68            68                 68           0
# maharastra          242           242                242           1
# rajasthan            86            86                 86           0
