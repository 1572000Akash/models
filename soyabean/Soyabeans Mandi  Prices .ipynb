# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
sp = pd.read_csv("C:/Users/RISHABH/Documents/SoyabeanPrices2019.csv")

# %%
sp.head(10)
# Out:
#             state   district     market commodity variety arrival_date  \
# 0  Madhya Pradesh  Alirajpur  Alirajpur  Soyabean   Other     02-01-19
# 1  Madhya Pradesh  Alirajpur  Alirajpur  Soyabean   Other     03-01-19
# 2  Madhya Pradesh  Alirajpur  Alirajpur  Soyabean   Other     04-01-19
# 3  Madhya Pradesh  Alirajpur  Alirajpur  Soyabean   Other     05-01-19
# 4  Madhya Pradesh  Alirajpur  Alirajpur  Soyabean   Other     07-01-19
# 5  Madhya Pradesh  Alirajpur  Alirajpur  Soyabean   Other     08-01-19
# 6  Madhya Pradesh  Alirajpur  Alirajpur  Soyabean   Other     09-01-19
# 7  Madhya Pradesh  Alirajpur  Alirajpur  Soyabean   Other     10-01-19
# 8  Madhya Pradesh  Alirajpur  Alirajpur  Soyabean   Other     11-01-19
# 9  Madhya Pradesh  Alirajpur  Alirajpur  Soyabean   Other     14-01-19
#
#    min_price  max_price  modal_price/Quintol
# 0     3200.0     3355.0               3280.0
# 1     3200.0     3400.0               3395.0
# 2     3200.0     3400.0               3395.0
# ...

# %%
sp.tail(10)
# Out:
#            state district   market commodity variety arrival_date  min_price  \
# 30787  Rajasthan  Udaipur  Udaipur  Soyabean   Other     17-07-19     3350.0
# 30788  Rajasthan  Udaipur  Udaipur  Soyabean   Other     22-07-19     3350.0
# 30789  Rajasthan  Udaipur  Udaipur  Soyabean   Other     23-07-19     3300.0
# 30790  Rajasthan  Udaipur  Udaipur  Soyabean   Other     24-07-19     3350.0
# 30791  Rajasthan  Udaipur  Udaipur  Soyabean   Other     25-07-19     3350.0
# 30792  Rajasthan  Udaipur  Udaipur  Soyabean   Other     29-07-19     3350.0
# 30793  Rajasthan  Udaipur  Udaipur  Soyabean   Other     31-07-19     3350.0
# 30794  Rajasthan  Udaipur  Udaipur  Soyabean   Other     02-08-19     3350.0
# 30795  Rajasthan  Udaipur  Udaipur  Soyabean   Other     05-08-19     3350.0
# 30796  Rajasthan  Udaipur  Udaipur  Soyabean   Other     08-08-19     3350.0
#
#        max_price  modal_price/Quintol
# 30787     3550.0               3450.0
# 30788     3550.0               3450.0
# ...

# %%
mp = sp[sp['state']=='Madhya Pradesh']

# %%
mp
# Out:
#                 state   district     market commodity variety arrival_date  \
# 0      Madhya Pradesh  Alirajpur  Alirajpur  Soyabean   Other     02-01-19
# 1      Madhya Pradesh  Alirajpur  Alirajpur  Soyabean   Other     03-01-19
# 2      Madhya Pradesh  Alirajpur  Alirajpur  Soyabean   Other     04-01-19
# 3      Madhya Pradesh  Alirajpur  Alirajpur  Soyabean   Other     05-01-19
# 4      Madhya Pradesh  Alirajpur  Alirajpur  Soyabean   Other     07-01-19
# 5      Madhya Pradesh  Alirajpur  Alirajpur  Soyabean   Other     08-01-19
# 6      Madhya Pradesh  Alirajpur  Alirajpur  Soyabean   Other     09-01-19
# 7      Madhya Pradesh  Alirajpur  Alirajpur  Soyabean   Other     10-01-19
# 8      Madhya Pradesh  Alirajpur  Alirajpur  Soyabean   Other     11-01-19
# 9      Madhya Pradesh  Alirajpur  Alirajpur  Soyabean   Other     14-01-19
# 10     Madhya Pradesh  Alirajpur  Alirajpur  Soyabean   Other     18-01-19
# ...

# %%
mh = sp[sp['state']=='Maharashtra']

# %%
mh
# Out:
#              state    district      market commodity variety arrival_date  \
# 17978  Maharashtra  Ahmednagar  Ahmednagar  Soyabean   Other     05-01-19
# 17979  Maharashtra  Ahmednagar  Ahmednagar  Soyabean   Other     10-01-19
# 17980  Maharashtra  Ahmednagar  Ahmednagar  Soyabean   Other     15-01-19
# 17981  Maharashtra  Ahmednagar  Ahmednagar  Soyabean   Other     16-01-19
# 17982  Maharashtra  Ahmednagar  Ahmednagar  Soyabean   Other     17-01-19
# 17983  Maharashtra  Ahmednagar  Ahmednagar  Soyabean   Other     28-01-19
# 17984  Maharashtra  Ahmednagar  Ahmednagar  Soyabean   Other     04-02-19
# 17985  Maharashtra  Ahmednagar  Ahmednagar  Soyabean   Other     21-02-19
# 17986  Maharashtra  Ahmednagar  Ahmednagar  Soyabean   Other     05-03-19
# 17987  Maharashtra  Ahmednagar  Ahmednagar  Soyabean   Other     08-03-19
# 17988  Maharashtra  Ahmednagar  Ahmednagar  Soyabean   Other     11-03-19
# 17989  Maharashtra  Ahmednagar  Ahmednagar  Soyabean   Other     12-03-19
# ...

# %%
rj = sp[sp['state']=='Rajasthan']

# %%
rj
# Out:
#            state district   market commodity variety arrival_date  min_price  \
# 28008  Rajasthan    Baran     Anta  Soyabean   Other     02-01-19     3140.0
# 28009  Rajasthan    Baran     Anta  Soyabean   Other     09-01-19     3231.0
# 28010  Rajasthan    Baran     Anta  Soyabean   Other     12-01-19     3051.0
# 28011  Rajasthan    Baran     Anta  Soyabean   Other     15-01-19     3400.0
# 28012  Rajasthan    Baran     Anta  Soyabean   Other     16-01-19     3391.0
# 28013  Rajasthan    Baran     Anta  Soyabean   Other     25-01-19     3575.0
# 28014  Rajasthan    Baran     Anta  Soyabean   Other     28-01-19     2650.0
# 28015  Rajasthan    Baran     Anta  Soyabean   Other     29-01-19     3350.0
# 28016  Rajasthan    Baran     Anta  Soyabean   Other     30-01-19     3350.0
# 28017  Rajasthan    Baran     Anta  Soyabean   Other     31-01-19     3382.0
# 28018  Rajasthan    Baran     Anta  Soyabean   Other     01-02-19     3072.0
# ...

# %%
count = rj.groupby(['district']).count() 
print(count)
# Out:
#                state  market  commodity  variety  arrival_date  min_price  \
# district
# Baran            659     659        659      659           659        659
# Bhilwara          13      13         13       13            13         13
# Bundi            312     312        312      312           312        312
# Chittorgarh      385     385        385      385           385        385
# Jhalawar         844     844        844      844           844        844
# Kota             502     502        502      502           502        502
# Swai Madhopur     33      33         33       33            33         33
# Tonk               6       6          6        6             6          6
# Udaipur           35      35         35       35            35         35
#
#                max_price  modal_price/Quintol
# district
# Baran                659                  659
# Bhilwara              13                   13
# Bundi                312                  312
# ...

# %%
count = mp.groupby(['district']).count() 
print(count)
# Out:
#              state  market  commodity  variety  arrival_date  min_price  \
# district
# Alirajpur      235     235        235      235           235        235
# Anupur           2       2          2        2             2          2
# Ashoknagar     423     423        423      423           423        423
# Badwani        181     181        181      181           181        181
# Betul          253     253        253      253           253        253
# Bhopal         472     472        472      472           472        472
# Burhanpur      129     129        129      129           129        129
# Chhatarpur     441     441        441      441           441        441
# Chhindwara     216     216        216      216           216        216
# Damoh          240     240        240      240           240        240
# Datia           12      12         12       12            12         12
# Dewas          913     913        913      913           913        913
# ...

# %%
count = mh.groupby(['district']).count() 
print(count)
# Out:
#             state  market  commodity  variety  arrival_date  min_price  \
# district
# Ahmednagar    461     461        461      461           461        461
# Akola         496     496        496      496           496        496
# Amarawati     588     588        588      588           588        588
# Aurangabad    120     120        120      120           120        120
# Beed          627     627        627      627           627        627
# Bhandara        7       7          7        7             7          7
# Buldhana     1161    1161       1161     1161          1161       1161
# Chandrapur    280     280        280      280           280        280
# Dhule          66      66         66       66            66         66
# Hingoli       578     578        578      578           578        578
# Jalana        383     383        383      383           383        383
# Jalgaon       222     222        222      222           222        222
# ...

# %%
mhtt = mh[['district','modal_price/Quintol']].groupby(['district'])['modal_price/Quintol'].count().nlargest(10)

# %%
mhtt
# Out:
# district
# Buldhana     1161
# Vashim        754
# Latur         750
# Wardha        735
# Beed          627
# Yavatmal      617
# Amarawati     588
# Hingoli       578
# Akola         496
# Nashik        469
# Name: modal_price/Quintol, dtype: int64

# %%
rjtt = rj[['district','modal_price/Quintol']].groupby(['district'])['modal_price/Quintol'].count().nlargest(10)

# %%
rjtt
# Out:
# district
# Jhalawar         844
# Baran            659
# Kota             502
# Chittorgarh      385
# Bundi            312
# Udaipur           35
# Swai Madhopur     33
# Bhilwara          13
# Tonk               6
# Name: modal_price/Quintol, dtype: int64

# %%
mptt = mp[['district','modal_price/Quintol']].groupby(['district'])['modal_price/Quintol'].count().nlargest(10)

# %%
mptt
# Out:
# district
# Shajapur    1544
# Rajgarh     1134
# Ujjain      1049
# Sagar        920
# Dewas        913
# Dhar         905
# Ratlam       886
# Sehore       820
# Vidisha      746
# Shivpuri     662
# Name: modal_price/Quintol, dtype: int64

# %%
mhtt = mh[['district','modal_price/Quintol']].groupby(['district'])['modal_price/Quintol'].count().nlargest(10)

# %%
mhtt
# Out:
# district
# Buldhana     1161
# Vashim        754
# Latur         750
# Wardha        735
# Beed          627
# Yavatmal      617
# Amarawati     588
# Hingoli       578
# Akola         496
# Nashik        469
# Name: modal_price/Quintol, dtype: int64

# %%
array = ['Shajapur', 'Rajgarh','Ujjain','Sagar','Dewas','Dhar','Ratlam','Sehore','Vidisha','Shivpuri']
tmp = mp.loc[mp['district'].isin(array)]

# %%
tmp
# Out:
#                 state district   market commodity variety arrival_date  \
# 2604   Madhya Pradesh    Dewas    Bagli  Soyabean   Other     02-01-19
# 2605   Madhya Pradesh    Dewas    Bagli  Soyabean   Other     03-01-19
# 2606   Madhya Pradesh    Dewas    Bagli  Soyabean   Other     05-01-19
# 2607   Madhya Pradesh    Dewas    Bagli  Soyabean   Other     07-01-19
# 2608   Madhya Pradesh    Dewas    Bagli  Soyabean   Other     08-01-19
# 2609   Madhya Pradesh    Dewas    Bagli  Soyabean   Other     09-01-19
# 2610   Madhya Pradesh    Dewas    Bagli  Soyabean   Other     10-01-19
# 2611   Madhya Pradesh    Dewas    Bagli  Soyabean   Other     11-01-19
# 2612   Madhya Pradesh    Dewas    Bagli  Soyabean   Other     15-01-19
# 2613   Madhya Pradesh    Dewas    Bagli  Soyabean   Other     16-01-19
# 2614   Madhya Pradesh    Dewas    Bagli  Soyabean   Other     17-01-19
# 2615   Madhya Pradesh    Dewas    Bagli  Soyabean   Other     18-01-19
# ...

# %%
tmp.tail(10)
# Out:
#                 state district   market commodity variety arrival_date  \
# 17968  Madhya Pradesh  Vidisha  Vidisha  Soyabean  Yellow     25-07-19
# 17969  Madhya Pradesh  Vidisha  Vidisha  Soyabean  Yellow     27-07-19
# 17970  Madhya Pradesh  Vidisha  Vidisha  Soyabean  Yellow     29-07-19
# 17971  Madhya Pradesh  Vidisha  Vidisha  Soyabean  Yellow     30-07-19
# 17972  Madhya Pradesh  Vidisha  Vidisha  Soyabean  Yellow     31-07-19
# 17973  Madhya Pradesh  Vidisha  Vidisha  Soyabean  Yellow     02-08-19
# 17974  Madhya Pradesh  Vidisha  Vidisha  Soyabean  Yellow     03-08-19
# 17975  Madhya Pradesh  Vidisha  Vidisha  Soyabean  Yellow     05-08-19
# 17976  Madhya Pradesh  Vidisha  Vidisha  Soyabean  Yellow     06-08-19
# 17977  Madhya Pradesh  Vidisha  Vidisha  Soyabean  Yellow     07-08-19
#
#        min_price  max_price  modal_price/Quintol
# 17968     2800.0     3325.0               3280.0
# 17969     2800.0     3320.0               3260.0
# ...

# %%
count = tmp.groupby(['district']).count() 
print(count)
# Out:
#           state  market  commodity  variety  arrival_date  min_price  \
# district
# Dewas       913     913        913      913           913        913
# Dhar        905     905        905      905           905        905
# Rajgarh    1134    1134       1134     1134          1134       1134
# Ratlam      886     886        886      886           886        886
# Sagar       920     920        920      920           920        920
# Sehore      820     820        820      820           820        820
# Shajapur   1544    1544       1544     1544          1544       1544
# Shivpuri    662     662        662      662           662        662
# Ujjain     1049    1049       1049     1049          1049       1049
# Vidisha     746     746        746      746           746        746
#
#           max_price  modal_price/Quintol
# district
# Dewas           913                  913
# Dhar            905                  905
# Rajgarh        1134                 1134
# ...

# %%
arr = ["Buldhana" ,"Vashim", "Latur","Wardha","Beed" , "Yavatmal" , "Amarawati" ,"Hingoli" ,"Akola" , "Nashik"]
tmh = mh.loc[mh['district'].isin(arr)]

# %%
tmh
# Out:
#              state  district      market commodity variety arrival_date  \
# 18439  Maharashtra     Akola       Akola  Soyabean  Yellow     01-01-19
# 18440  Maharashtra     Akola       Akola  Soyabean  Yellow     02-01-19
# 18441  Maharashtra     Akola       Akola  Soyabean  Yellow     03-01-19
# 18442  Maharashtra     Akola       Akola  Soyabean  Yellow     04-01-19
# 18443  Maharashtra     Akola       Akola  Soyabean  Yellow     05-01-19
# 18444  Maharashtra     Akola       Akola  Soyabean  Yellow     07-01-19
# 18445  Maharashtra     Akola       Akola  Soyabean  Yellow     08-01-19
# 18446  Maharashtra     Akola       Akola  Soyabean  Yellow     09-01-19
# 18447  Maharashtra     Akola       Akola  Soyabean  Yellow     10-01-19
# 18448  Maharashtra     Akola       Akola  Soyabean  Yellow     11-01-19
# 18449  Maharashtra     Akola       Akola  Soyabean  Yellow     12-01-19
# 18450  Maharashtra     Akola       Akola  Soyabean  Yellow     14-01-19
# ...

# %%
count = tmh.groupby(['district']).count() 
print(count)
# Out:
#            state  market  commodity  variety  arrival_date  min_price  \
# district
# Akola        496     496        496      496           496        496
# Amarawati    588     588        588      588           588        588
# Beed         627     627        627      627           627        627
# Buldhana    1161    1161       1161     1161          1161       1161
# Hingoli      578     578        578      578           578        578
# Latur        750     750        750      750           750        750
# Nashik       469     469        469      469           469        469
# Vashim       754     754        754      754           754        754
# Wardha       735     735        735      735           735        735
# Yavatmal     617     617        617      617           617        617
#
#            max_price  modal_price/Quintol
# district
# Akola            496                  496
# Amarawati        588                  588
# Beed             627                  627
# ...

# %%
arrr =["Jhalawar" ,"Baran", "Kota","Chittorgarh","Bundi" , "Udaipur" , "Swai Madhopur" ,"Bhilwara" ,"Tonk" ]
trj = rj.loc[rj['district'].isin(arrr)]

# %%
trj
# Out:
#            state district   market commodity variety arrival_date  min_price  \
# 28008  Rajasthan    Baran     Anta  Soyabean   Other     02-01-19     3140.0
# 28009  Rajasthan    Baran     Anta  Soyabean   Other     09-01-19     3231.0
# 28010  Rajasthan    Baran     Anta  Soyabean   Other     12-01-19     3051.0
# 28011  Rajasthan    Baran     Anta  Soyabean   Other     15-01-19     3400.0
# 28012  Rajasthan    Baran     Anta  Soyabean   Other     16-01-19     3391.0
# 28013  Rajasthan    Baran     Anta  Soyabean   Other     25-01-19     3575.0
# 28014  Rajasthan    Baran     Anta  Soyabean   Other     28-01-19     2650.0
# 28015  Rajasthan    Baran     Anta  Soyabean   Other     29-01-19     3350.0
# 28016  Rajasthan    Baran     Anta  Soyabean   Other     30-01-19     3350.0
# 28017  Rajasthan    Baran     Anta  Soyabean   Other     31-01-19     3382.0
# 28018  Rajasthan    Baran     Anta  Soyabean   Other     01-02-19     3072.0
# ...

# %%
count = trj.groupby(['district']).count() 
print(count)
# Out:
#                state  market  commodity  variety  arrival_date  min_price  \
# district
# Baran            659     659        659      659           659        659
# Bhilwara          13      13         13       13            13         13
# Bundi            312     312        312      312           312        312
# Chittorgarh      385     385        385      385           385        385
# Jhalawar         844     844        844      844           844        844
# Kota             502     502        502      502           502        502
# Swai Madhopur     33      33         33       33            33         33
# Tonk               6       6          6        6             6          6
# Udaipur           35      35         35       35            35         35
#
#                max_price  modal_price/Quintol
# district
# Baran                659                  659
# Bhilwara              13                   13
# Bundi                312                  312
# ...

# %%
avrj = trj.groupby([pd.to_datetime(trj.arrival_date).dt.strftime('%b'), 'district'])['modal_price/Quintol'].mean().reset_index(name='modal_price/Quintol')

# %%
avrj
# Out:
#    arrival_date       district  modal_price/Quintol
# 0           Apr          Baran          3611.750000
# 1           Apr       Bhilwara          3588.500000
# 2           Apr          Bundi          3539.423077
# 3           Apr    Chittorgarh          3660.076923
# 4           Apr       Jhalawar          3656.770115
# 5           Apr           Kota          3596.959184
# 6           Apr  Swai Madhopur          3275.000000
# 7           Apr           Tonk          3000.000000
# 8           Apr        Udaipur          3325.000000
# 9           Aug          Baran          3525.541667
# 10          Aug       Bhilwara          3750.000000
# 11          Aug          Bundi          3483.150000
# 12          Aug    Chittorgarh          3505.812500
# 13          Aug       Jhalawar          3583.891892
# 14          Aug           Kota          3553.100000
# 15          Aug  Swai Madhopur          3291.000000
# 16          Aug        Udaipur          3500.000000
# ...

# %%
avmp = tmp.groupby([pd.to_datetime(tmp.arrival_date).dt.strftime('%b'), 'district'])['modal_price/Quintol'].mean().reset_index(name='modal_price/Quintol')

# %%
avmp
# Out:
#     arrival_date  district  modal_price/Quintol
# 0            Apr     Dewas          3516.800000
# 1            Apr      Dhar          3512.872093
# 2            Apr   Rajgarh          3529.809524
# 3            Apr    Ratlam          3599.787879
# 4            Apr     Sagar          3425.295918
# 5            Apr    Sehore          3523.488372
# 6            Apr  Shajapur          3512.525974
# 7            Apr  Shivpuri          3530.485294
# 8            Apr    Ujjain          3270.900000
# 9            Apr   Vidisha          3382.000000
# 10           Aug     Dewas          3465.833333
# 11           Aug      Dhar          3404.567568
# 12           Aug   Rajgarh          3499.086957
# 13           Aug    Ratlam          3624.387097
# 14           Aug     Sagar          3423.162162
# 15           Aug    Sehore          3526.545455
# 16           Aug  Shajapur          3476.622951
# 17           Aug  Shivpuri          3478.925926
# 18           Aug    Ujjain          3265.956098
# ...

# %%
count = avmp.groupby(['district']).count() 
print(count)
# Out:
#           arrival_date  modal_price/Quintol
# district
# Dewas               12                   12
# Dhar                12                   12
# Rajgarh             12                   12
# Ratlam              12                   12
# Sagar               12                   12
# Sehore              12                   12
# Shajapur            12                   12
# Shivpuri            12                   12
# Ujjain              12                   12
# Vidisha             12                   12

# %%
avmh = tmh.groupby([pd.to_datetime(tmh.arrival_date).dt.strftime('%b'), 'district'])['modal_price/Quintol'].mean().reset_index(name='modal_price/Quintol')

# %%
avmh
# Out:
#     arrival_date   district  modal_price/Quintol
# 0            Apr      Akola          3525.250000
# 1            Apr  Amarawati          3447.295455
# 2            Apr       Beed          3600.016393
# 3            Apr   Buldhana          3469.136842
# 4            Apr    Hingoli          3562.283019
# 5            Apr      Latur          3620.333333
# 6            Apr     Nashik          3559.760000
# 7            Apr     Vashim          3575.095890
# 8            Apr     Wardha          3487.876712
# 9            Apr   Yavatmal          3535.316667
# 10           Aug      Akola          3444.761905
# 11           Aug  Amarawati          3396.483871
# 12           Aug       Beed          3547.064516
# 13           Aug   Buldhana          3446.074074
# 14           Aug    Hingoli          3511.416667
# 15           Aug      Latur          3580.777778
# 16           Aug     Nashik          3514.954545
# 17           Aug     Vashim          3534.485714
# ...

# %%
count = avmh.groupby(['district']).count() 
print(count)
# Out:
#            arrival_date  modal_price/Quintol
# district
# Akola                12                   12
# Amarawati            12                   12
# Beed                 12                   12
# Buldhana             12                   12
# Hingoli              12                   12
# Latur                12                   12
# Nashik               12                   12
# Vashim               12                   12
# Wardha               12                   12
# Yavatmal             12                   12

# %%
avmh
# Out:
#     arrival_date   district  modal_price/Quintol
# 0            Apr      Akola          3525.250000
# 1            Apr  Amarawati          3447.295455
# 2            Apr       Beed          3600.016393
# 3            Apr   Buldhana          3469.136842
# 4            Apr    Hingoli          3562.283019
# 5            Apr      Latur          3620.333333
# 6            Apr     Nashik          3559.760000
# 7            Apr     Vashim          3575.095890
# 8            Apr     Wardha          3487.876712
# 9            Apr   Yavatmal          3535.316667
# 10           Aug      Akola          3444.761905
# 11           Aug  Amarawati          3396.483871
# 12           Aug       Beed          3547.064516
# 13           Aug   Buldhana          3446.074074
# 14           Aug    Hingoli          3511.416667
# 15           Aug      Latur          3580.777778
# 16           Aug     Nashik          3514.954545
# 17           Aug     Vashim          3534.485714
# ...

# %%
avmh
# Out:
#     arrival_date   district  modal_price/Quintol
# 0            Apr      Akola          3525.250000
# 1            Apr  Amarawati          3447.295455
# 2            Apr       Beed          3600.016393
# 3            Apr   Buldhana          3469.136842
# 4            Apr    Hingoli          3562.283019
# 5            Apr      Latur          3620.333333
# 6            Apr     Nashik          3559.760000
# 7            Apr     Vashim          3575.095890
# 8            Apr     Wardha          3487.876712
# 9            Apr   Yavatmal          3535.316667
# 10           Aug      Akola          3444.761905
# 11           Aug  Amarawati          3396.483871
# 12           Aug       Beed          3547.064516
# 13           Aug   Buldhana          3446.074074
# 14           Aug    Hingoli          3511.416667
# 15           Aug      Latur          3580.777778
# 16           Aug     Nashik          3514.954545
# 17           Aug     Vashim          3534.485714
# ...

# %%
avrj['arrival_date'] = pd.Categorical(avrj['arrival_date'],categories=['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'],ordered=True)
avrj = avrj.sort_values('arrival_date',ascending=True)

# %%
avrj
# Out:
#    arrival_date       district  modal_price/Quintol
# 40          Jan           Tonk          3050.000000
# 39          Jan  Swai Madhopur          3571.500000
# 38          Jan           Kota          3495.741935
# 37          Jan       Jhalawar          3604.598131
# 36          Jan    Chittorgarh          3592.019608
# 35          Jan          Bundi          3550.967391
# 34          Jan       Bhilwara          3550.000000
# 33          Jan          Baran          3596.769231
# 41          Jan        Udaipur          3500.000000
# 30          Feb  Swai Madhopur          3541.250000
# 26          Feb          Bundi          3562.238636
# 27          Feb    Chittorgarh          3560.442308
# 28          Feb       Jhalawar          3550.591837
# 25          Feb          Baran          3543.467532
# 31          Feb           Tonk          3100.000000
# 32          Feb        Udaipur          3450.000000
# 29          Feb           Kota          3508.305085
# ...

# %%
avmh['arrival_date'] = pd.Categorical(avmh['arrival_date'],categories=['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'],ordered=True)
avmh = avmh.sort_values('arrival_date',ascending=True)

# %%
avmh
# Out:
#     arrival_date   district  modal_price/Quintol
# 49           Jan   Yavatmal          3530.753968
# 48           Jan     Wardha          3485.069565
# 47           Jan     Vashim          3598.535354
# 46           Jan     Nashik          3633.792453
# 45           Jan      Latur          3618.863636
# 44           Jan    Hingoli          3562.440860
# 43           Jan   Buldhana          3552.031847
# 42           Jan       Beed          3599.133333
# 41           Jan  Amarawati          3462.109890
# 40           Jan      Akola          3523.483333
# 36           Feb     Nashik          3578.277778
# 31           Feb  Amarawati          3453.625000
# 32           Feb       Beed          3590.125000
# 33           Feb   Buldhana          3505.595041
# 34           Feb    Hingoli          3572.941176
# 30           Feb      Akola          3488.980000
# 37           Feb     Vashim          3562.600000
# 38           Feb     Wardha          3475.550562
# ...

# %%
avmp['arrival_date'] = pd.Categorical(avmp['arrival_date'],categories=['Jan','Feb','Mar','Apr','May','Jun','Jul','Aug','Sep','Oct','Nov','Dec'],ordered=True)
avmp = avmp.sort_values('arrival_date',ascending=True)

# %%
avmp
# Out:
#     arrival_date  district  modal_price/Quintol
# 49           Jan   Vidisha          3475.769231
# 48           Jan    Ujjain          3280.304615
# 47           Jan  Shivpuri          3513.547170
# 46           Jan  Shajapur          3550.031088
# 45           Jan    Sehore          3580.150442
# 44           Jan     Sagar          3448.550336
# 43           Jan    Ratlam          3607.105769
# 42           Jan   Rajgarh          3553.826667
# 41           Jan      Dhar          3565.793893
# 40           Jan     Dewas          3506.731481
# 36           Feb  Shajapur          3532.883598
# 31           Feb      Dhar          3546.297030
# 32           Feb   Rajgarh          3536.704225
# 33           Feb    Ratlam          3590.928571
# 34           Feb     Sagar          3430.963303
# 30           Feb     Dewas          3488.366667
# 37           Feb  Shivpuri          3534.838384
# 38           Feb    Ujjain          3432.686486
# 39           Feb   Vidisha          3434.840000
# ...

# %%
import seaborn as sns

# %%
# ax = sns.scatterplot(x='arrival_date', y='modal_price/Quintol', data=avmp , color = 'green')
plt.figure(figsize = (16,8))
bx = sns.scatterplot(x='arrival_date', y='modal_price/Quintol', hue = 'district' ,data=avmp )
bx.set(xticks=np.arange(1, 12, 1),
      yticks=np.arange(3300, 3700, 50))
# bx.plot()
# Out:
# [[<matplotlib.axis.YTick at 0x1be7b23ccf8>,
# ...

# %%
# ax = sns.scatterplot(x='arrival_date', y='modal_price/Quintol', data=avmp , color = 'green')
plt.figure(figsize = (16,8))
bx = sns.scatterplot(x='arrival_date', y='modal_price/Quintol', hue = 'district' ,data=avmh )
bx.set(xticks=np.arange(1, 12, 1),
      yticks=np.arange(3400, 3700, 50))
# bx.plot()
# Out:
# [[<matplotlib.axis.YTick at 0x1be7b5f3978>,
# ...

# %%
# ax = sns.scatterplot(x='arrival_date', y='modal_price/Quintol', data=avmp , color = 'green')
plt.figure(figsize = (16,8))
bx = sns.scatterplot(x='arrival_date', y='modal_price/Quintol', hue = 'district' ,data=avrj )
bx.set(xticks=np.arange(1, 12, 1),
      yticks=np.arange(3100, 3800, 100))
# bx.plot()
# Out:
# [[<matplotlib.axis.YTick at 0x1be7b3cd438>,
# ...

# %%
# ax = sns.scatterplot(x='arrival_date', y='modal_price/Quintol', data=avmp , color = 'green')
import matplotlib.pyplot as plt

plt.figure(figsize = (16,24))
bx =sns.catplot(x="arrival_date", y="modal_price/Quintol", hue="district", kind="point", data=avmp);

bx.set(xticks=np.arange(0, 13, 1),
      yticks=np.arange(3000, 3800,100 ))
# bx.plot()

# %%
# ax = sns.scatterplot(x='arrival_date', y='modal_price/Quintol', data=avmp , color = 'green')
plt.figure(figsize = (16,8))
bx =sns.catplot(x="arrival_date", y="modal_price/Quintol", hue="district", kind="point", data=avmh);

bx.set(xticks=np.arange(0, 13, 1),
      yticks=np.arange(3400, 3700, 50))
# bx.plot()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")
# plt.figure(figsize = (16,8))
bx = sns.relplot(x="arrival_date", y="modal_price/Quintol", hue="district",dashes=False, markers=True, kind="line", data = avrj);
bx.set(xticks=np.arange(0, 13, 1),
      yticks=np.arange(3100, 3800, 100))
# Out:
# E:\Anaconda\lib\site-packages\seaborn\algorithms.py:70: RuntimeWarning: Mean of empty slice.
#   return getattr(x, func)()
# E:\Anaconda\lib\site-packages\numpy\core\_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
avmp.insert(3,'Production',None)

# %%
avmp
# Out:
#     arrival_date  district  modal_price/Quintol Production
# 49           Jan   Vidisha          3475.769231       None
# 48           Jan    Ujjain          3280.304615       None
# 47           Jan  Shivpuri          3513.547170       None
# 46           Jan  Shajapur          3550.031088       None
# 45           Jan    Sehore          3580.150442       None
# 44           Jan     Sagar          3448.550336       None
# 43           Jan    Ratlam          3607.105769       None
# 42           Jan   Rajgarh          3553.826667       None
# 41           Jan      Dhar          3565.793893       None
# 40           Jan     Dewas          3506.731481       None
# 36           Feb  Shajapur          3532.883598       None
# 31           Feb      Dhar          3546.297030       None
# 32           Feb   Rajgarh          3536.704225       None
# 33           Feb    Ratlam          3590.928571       None
# 34           Feb     Sagar          3430.963303       None
# ...

# %%
avmp.to_csv('C:/Users/RISHABH/Documents/NEWSOYAMP.csv')

# %%
avrj.to_csv('C:/Users/RISHABH/Documents/NEWSOYARJ.csv')

# %%
avmh.to_csv('C:/Users/RISHABH/Documents/NEWSOYA.csv')

# %%
avmhn =pd.read_csv(('C:/Users/RISHABH/Documents/NEWSOYAMH.csv'))

# %%
# Out:
#    Unnamed: 0 arrival_date  district  modal_price/Quintol  Sold Amount
# 0          49          Jan   Vidisha          3475.769231      53370.0
# 1          48          Jan    Ujjain          3280.304615     213750.0
# 2          47          Jan  Shivpuri          3513.547170      13180.0
# 3          46          Jan  Shajapur          3550.031088      43839.0
# 4          45          Jan    Sehore          3580.150442      80840.0

# %%
avrjn =pd.read_csv('C:/Users/RISHABH/Downloads/NNEWSOYARJ.csv')

# %%
avrjn
# Out:
#     Unnamed: 0 arrival_date       district  modal_price/Quintol  Production
# 0           40          Jan           Tonk          3050.000000       0.156
# 1           39          Jan  Swai Madhopur          3571.500000       0.124
# 2           38          Jan           Kota          3495.741935       0.953
# 3           37          Jan       Jhalawar          3604.598131       1.223
# 4           36          Jan    Chittorgarh          3592.019608       0.644
# 5           35          Jan          Bundi          3550.967391       0.351
# 6           34          Jan       Bhilwara          3550.000000       0.037
# 7           33          Jan          Baran          3596.769231       1.478
# 8           41          Jan        Udaipur          3500.000000       0.179
# 9           30          Feb  Swai Madhopur          3541.250000       0.124
# 10          26          Feb          Bundi          3562.238636       0.351
# ...

# %%
avmpn =pd.read_csv('C:/Users/RISHABH/Documents/NNEWSOYAMP .csv')

# %%
avmpn
# Out:
#      Unnamed: 0 arrival_date  district  modal_price/Quintol  Production
# 0            49          Jan   Vidisha          3475.769231       2.205
# 1            48          Jan    Ujjain          3280.304615       3.822
# 2            47          Jan  Shivpuri          3513.547170       1.074
# 3            46          Jan  Shajapur          3550.031088       1.941
# 4            45          Jan    Sehore          3580.150442       2.154
# 5            44          Jan     Sagar          3448.550336       1.874
# 6            43          Jan    Ratlam          3607.105769       1.679
# 7            42          Jan   Rajgarh          3553.826667       2.351
# 8            41          Jan      Dhar          3565.793893       2.739
# 9            40          Jan     Dewas          3506.731481       2.890
# 10           36          Feb  Shajapur          3532.883598       1.941
# 11           31          Feb      Dhar          3546.297030       2.739
# ...

# %%
import plotly.express as px

# %%
import plotly.express as px
# iris = px.data.iris()
fig = px.scatter_3d(avmpn, x=avmpn['arrival_date'], y=avmpn['modal_price/Quintol'], z=avmpn['Sold Amoun'],color ='district')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-476ea64edacf> in <module>()
#       1 import plotly.express as px
#       2 # iris = px.data.iris()
# ----> 3 fig = px.scatter_3d(avmpn, x=avmpn['arrival_date'], y=avmpn['modal_price/Quintol'], z=avmpn['Sold Amoun'],color ='district')
#       4 fig.show()
#
# NameError: name 'avmpn' is not defined

# %%
import plotly.express as px
# iris = px.data.iris()
fig = px.scatter_3d(avmhn, x=avmhn['arrival_date'], y=avmhn['modal_price/Quintol'], z=avmhn['Production'],color ='district')
fig.show()
# Out:
# <div>
#
#
#             <div id="08655642-1669-47bc-a57e-a7289adcd6b9" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("08655642-1669-47bc-a57e-a7289adcd6b9")) {
#                     Plotly.newPlot(
#                         '08655642-1669-47bc-a57e-a7289adcd6b9',
# ...

# %%
import plotly.express as px
# iris = px.data.iris()
fig = px.scatter_3d(avrjn, x=avrjn['arrival_date'], y=avrjn['modal_price/Quintol'], z=avrjn['Production'],color ='district')
fig.show()
# Out:
# <div>
#
#
#             <div id="a1c9d16e-fd3c-4823-a2bf-a3c627bafcab" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a1c9d16e-fd3c-4823-a2bf-a3c627bafcab")) {
#                     Plotly.newPlot(
#                         'a1c9d16e-fd3c-4823-a2bf-a3c627bafcab',
# ...

# %%
avvmpn =pd.read_csv('C:/Users/RISHABH/Documents/PNEWSOYAMP.csv')

# %%
avvmpn
# Out:
#      Unnamed: 0 Month  district  modal_price/Quintol  Amount_Sold(Quintol)
# 0            49   Jan   Vidisha          3475.769231               53370.0
# 1            48   Jan    Ujjain          3280.304615              213750.0
# 2            47   Jan  Shivpuri          3513.547170               13180.0
# 3            46   Jan  Shajapur          3550.031088               43839.0
# 4            45   Jan    Sehore          3580.150442               80840.0
# 5            44   Jan     Sagar          3448.550336               65066.0
# 6            43   Jan    Ratlam          3607.105769              127135.8
# 7            42   Jan   Rajgarh          3553.826667               82769.0
# 8            41   Jan      Dhar          3565.793893              149761.0
# 9            40   Jan     Dewas          3506.731481              282214.0
# 10           36   Feb   Vidisha          3532.883598               11991.0
# ...

# %%
import plotly.express as px
# iris = px.data.iris()
fig = px.scatter_3d(avvmpn, x=avvmpn['Month'], y=avvmpn['modal_price/Quintol'], z=avvmpn['Amount_Sold(Quintol)'],color ='district')
fig.show()
# Out:
# <div>
#
#
#             <div id="4cfcd177-8407-4455-9d3f-2d67c41164f7" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4cfcd177-8407-4455-9d3f-2d67c41164f7")) {
#                     Plotly.newPlot(
#                         '4cfcd177-8407-4455-9d3f-2d67c41164f7',
# ...
