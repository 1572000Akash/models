# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
sawer=pd.read_csv('SawerData.csv',index_col=[0],parse_dates=True,squeeze=True)

# %%
sawer.head()
# Out:
#            Market Name Commodity Variety Grade  Min Price (Rs./Quintal)  \
# Date
# 2017-01-04      Sanwer  Soyabean  Yellow   FAQ                     2700
# 2017-01-06      Sanwer  Soyabean  Yellow   FAQ                     2700
# 2017-01-07      Sanwer  Soyabean  Yellow   FAQ                     2730
# 2017-01-09      Sanwer  Soyabean  Yellow   FAQ                     2681
# 2017-01-10      Sanwer  Soyabean  Yellow   FAQ                     2675
#
#             Max Price (Rs./Quintal)  Modal Price (Rs./Quintal)  \
# Date
# 2017-01-04                     3005                       2839
# 2017-01-06                     3000                       2950
# 2017-01-07                     2996                       2850
# 2017-01-09                     2903                       2825
# 2017-01-10                     2888                       2775
#
#             Arrival/Quintol
# Date
# 2017-01-04           2133.7
# 2017-01-06           2133.7
# 2017-01-07           2133.7
# ...

# %%
type(sawer)
# Out:
# pandas.core.frame.DataFrame

# %%
sawer.drop(['Commodity', 'Variety','Variety','Grade','Min Price (Rs./Quintal)','Max Price (Rs./Quintal)'], axis = 1,inplace=True)

# %%
sawer
# Out:
#            Market Name  Modal Price (Rs./Quintal)  Arrival/Quintol
# Date
# 2017-01-04      Sanwer                       2839           2133.7
# 2017-01-06      Sanwer                       2950           2133.7
# 2017-01-07      Sanwer                       2850           2133.7
# 2017-01-09      Sanwer                       2825           2133.7
# 2017-01-10      Sanwer                       2775           2133.7
# 2017-01-11      Sanwer                       2870           2133.7
# 2017-01-12      Sanwer                       2825           2133.7
# 2017-01-13      Sanwer                       2811           2133.7
# 2017-01-16      Sanwer                       2803           2133.7
# 2017-01-17      Sanwer                       2811           2133.7
# 2017-01-20      Sanwer                       2908           2133.7
# 2017-01-21      Sanwer                       2840           2133.7
# 2017-01-23      Sanwer                       2821           2133.7
# ...
