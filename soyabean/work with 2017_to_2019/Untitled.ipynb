# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dfC=pd.read_csv("caster2017to2019.csv")

# %%
dfM=pd.read_csv("mustard2017to2019.csv")

# %%
dfS=pd.read_csv("soyabean_2017_to_2019.csv")

# %%
districtC= dfC['District Name']

# %%
lc=list(districtC)

# %%
districtM= dfM['District Name']

# %%
lm=list(districtM)

# %%
districtS= dfS['District Name']

# %%
ls=list(districtS)

# %%
samedistrict=[]

# %%
for i in range(0,175698):
    if ls[i] in lc:
            samedistrict.append(ls[i])

# %%
samedistrict
# Out:
# ['Surat',
#  'Surat',
#  'Surat',
#  'Surat',
#  'Haveri',
#  'Badwani',
#  'Khargone',
#  'Khargone',
#  'Dhar',
#  'Khargone',
#  'Amarawati',
#  'Latur',
#  'Jalana',
#  'Buldhana',
#  'Buldhana',
#  'Amarawati',
#  'Pune',
#  'Latur',
#  'Hingoli',
#  'Beed',
#  'Beed',
#  'Hingoli',
#  'Nagpur',
#  'Nandurbar',
#  'Osmanabad',
#  'Pune',
#  'Nashik',
#  'Latur',
#  'Latur',
#  'Nizamabad',
#  'Nizamabad',
#  'Medak',
#  'Amreli',
#  'Sabarkantha',
#  'Dahod',
#  'Sabarkantha',
#  'Rajkot',
#  'Rajkot',
#  'Sabarkantha',
#  'Jamnagar',
#  'Rajkot',
#  'Junagarh',
#  'Sabarkantha',
#  'Surat',
#  'Surat',
#  'Surat',
#  'Surat',
#  'Vadodara(Baroda)',
#  'Surat',
#  'Surat',
#  'Haveri',
#  'Haveri',
#  'Haveri',
#  'Dhar',
#  'Khargone',
#  'Khargone',
#  'Chhindwara',
#  'Dewas',
#  'Dhar',
#  'Dhar',
#  'Narsinghpur',
#  'Dhar',
#  'Dewas',
#  'Harda',
#  'Indore',
#  'Dewas',
#  'Khargone',
#  'Dewas',
#  'Harda',
#  'Dewas',
#  'Dhar',
#  'Narsinghpur',
#  'Dhar',
# ...

# %%
samedistrict1=[]

# %%
for j in range(0,175698):
    if ls[j] in lm:
            samedistrict1.append(ls[j])

# %%
samedistrict1
# Out:
# ['Shajapur',
#  'Shajapur',
#  'Shajapur',
#  'Shajapur',
#  'Shajapur',
#  'Shajapur',
#  'Shajapur',
#  'Shajapur',
#  'Shajapur',
#  'Shajapur',
#  'Shajapur',
#  'Shajapur',
#  'Shajapur',
#  'Shajapur',
#  'Shajapur',
#  'Shajapur',
#  'Shajapur',
#  'Shajapur',
#  'Shajapur',
#  'Shajapur',
#  'Shajapur',
#  'Shajapur',
#  'Shajapur',
#  'Shajapur',
#  'Shajapur',
#  'Shajapur',
#  'Shajapur',
#  'Shajapur',
#  'Shajapur',
#  'Shajapur',
#  'Shajapur',
#  'Shajapur',
#  'Shajapur',
#  'Shajapur',
#  'Shajapur',
#  'Shajapur',
#  'Shajapur',
#  'Shajapur',
#  'Shajapur',
#  'Shajapur',
#  'Shajapur',
#  'Shajapur',
#  'Shajapur',
#  'Shajapur',
#  'Shajapur',
#  'Shajapur',
#  'Shajapur',
#  'Shajapur',
#  'Shajapur',
#  'Shajapur',
#  'Shajapur',
#  'Shajapur',
#  'Shajapur',
#  'Shajapur',
#  'Shajapur',
#  'Shajapur',
#  'Shajapur',
#  'Shajapur',
#  'Shajapur',
#  'Shajapur',
#  'Shajapur',
#  'Shajapur',
#  'Shajapur',
#  'Shajapur',
#  'Shajapur',
#  'Shajapur',
# ...
