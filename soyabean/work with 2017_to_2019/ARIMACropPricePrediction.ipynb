# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats
import seaborn as sns
# from fbprophet import Prophet
#import chart_studio as py
import plotly.graph_objs as go

# %%
ls  = pd.read_csv('Soyabean5L.csv')

# %%
ls
# Out:
#         Sl no. District Name         Market Name Commodity   Variety   Grade  \
# 0            1       Chittor         Madanapalli  Soyabean  Soyabeen  Medium
# 1            2       Chittor         Madanapalli  Soyabean     Local  Medium
# 2            3       Chittor         Madanapalli  Soyabean  Soyabeen  Medium
# 3            4       Chittor         Madanapalli  Soyabean  Soyabeen  Medium
# 4            5       Chittor         Madanapalli  Soyabean  Soyabeen  Medium
# ...        ...           ...                 ...       ...       ...     ...
# 503629  503630     Dehradoon          Vikasnagar  Soyabean     Other     FAQ
# 503630  503631       Bankura  Bishnupur(Bankura)  Soyabean     Other     FAQ
# 503631  503632       Bankura  Bishnupur(Bankura)  Soyabean     Other     FAQ
# 503632  503633       Bankura  Bishnupur(Bankura)  Soyabean     Other     FAQ
# 503633  503634       Bankura  Bishnupur(Bankura)  Soyabean     Other     FAQ
#
# ...

# %%
ls = ls.drop(ls.columns[[0,2,3,4,5,6,7]], axis=1)

# %%
ls
# Out:
#           District Name  Modal Price (Rs./Quintal)       Date
# 0               Chittor                     2700.0  08-Dec-15
# 1               Chittor                     2700.0  07-Dec-15
# 2               Chittor                     2700.0  30-Nov-15
# 3               Chittor                     2700.0  29-Nov-15
# 4               Chittor                     2700.0  28-Nov-15
# 5               Saharsa                     8100.0  12-Feb-15
# 6               Saharsa                     8150.0  11-Feb-15
# 7               Saharsa                     8250.0  10-Feb-15
# 8               Saharsa                     8100.0  09-Feb-15
# 9                Raipur                     3255.0  30-Nov-19
# 10               Raipur                     3732.0  31-Oct-19
# 11               Raipur                     3556.0  31-Jul-19
# 12               Raipur                     3630.0  02-Jul-19
# 13               Raipur                     3630.0  01-Jul-19
# ...

# %%
ls['Date']=pd.to_datetime(ls['Date'])

# %%
# ls = ls.groupby([pd.to_datetime(ls.Date).dt.strftime('%b%Y'),'District Name'])['Modal Price (Rs./Quintal)'].mean().reset_index(name='Modal Price (Rs./Quintal)')

# %%
ls
# Out:
#        District Name  Modal Price (Rs./Quintal)       Date
# 0            Chittor                     2700.0 2015-12-08
# 1            Chittor                     2700.0 2015-12-07
# 2            Chittor                     2700.0 2015-11-30
# 3            Chittor                     2700.0 2015-11-29
# 4            Chittor                     2700.0 2015-11-28
# ...              ...                        ...        ...
# 503629     Dehradoon                     2500.0 2016-03-09
# 503630       Bankura                     5200.0 2013-11-02
# 503631       Bankura                     5300.0 2013-10-09
# 503632       Bankura                     5400.0 2013-09-03
# 503633       Bankura                     5400.0 2013-07-03
#
# [503634 rows x 3 columns]

# %%
nk = ls[ls['District Name']=='Indore']

# %%
nk
# Out:
#        District Name  Modal Price (Rs./Quintal)       Date
# 119815        Indore                     3800.0 2019-12-06
# 119816        Indore                     3750.0 2019-12-05
# 119817        Indore                     3850.0 2019-12-04
# 119818        Indore                     3820.0 2019-12-03
# 119819        Indore                     3800.0 2019-12-02
# ...              ...                        ...        ...
# 244097        Indore                     2285.0 2010-01-06
# 244098        Indore                     2302.0 2010-01-05
# 244099        Indore                     2300.0 2010-01-04
# 244100        Indore                     2265.0 2010-01-02
# 244101        Indore                     2300.0 2010-01-01
#
# [8373 rows x 3 columns]

# %%
nk.columns = [str(x).lower().replace(' ', '_') for x in nk.columns]

# %%
nk
# Out:
#        district_name  modal_price_(rs./quintal)       date
# 119815        Indore                     3800.0 2019-12-06
# 119816        Indore                     3750.0 2019-12-05
# 119817        Indore                     3850.0 2019-12-04
# 119818        Indore                     3820.0 2019-12-03
# 119819        Indore                     3800.0 2019-12-02
# ...              ...                        ...        ...
# 244097        Indore                     2285.0 2010-01-06
# 244098        Indore                     2302.0 2010-01-05
# 244099        Indore                     2300.0 2010-01-04
# 244100        Indore                     2265.0 2010-01-02
# 244101        Indore                     2300.0 2010-01-01
#
# [8373 rows x 3 columns]

# %%
nk.sort_values(by='date', inplace=True, ascending=True)
# Out:
# /home/akash/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
nk
# Out:
#        district_name  modal_price_(rs./quintal)       date
# 244101        Indore                     2300.0 2010-01-01
# 136351        Indore                     2300.0 2010-01-01
# 136350        Indore                     2290.0 2010-01-02
# 244100        Indore                     2265.0 2010-01-02
# 244099        Indore                     2300.0 2010-01-04
# ...              ...                        ...        ...
# 241763        Indore                     3870.0 2019-12-05
# 133870        Indore                     3800.0 2019-12-06
# 119815        Indore                     3800.0 2019-12-06
# 241762        Indore                     3800.0 2019-12-07
# 133869        Indore                     3900.0 2019-12-07
#
# [8373 rows x 3 columns]

# %%
nk = nk.groupby([pd.to_datetime(nk.date).dt.strftime('%b%Y'),'district_name'])['modal_price_(rs./quintal)'].mean().reset_index(name='modal_price_(rs./quintal)')

# %%
nk
# Out:
#         date district_name  modal_price_(rs./quintal)
# 0    Apr2010        Indore                1893.600000
# 1    Apr2011        Indore                2117.925000
# 2    Apr2012        Indore                2917.300000
# 3    Apr2013        Indore                3381.879310
# 4    Apr2014        Indore                4149.351351
# ..       ...           ...                        ...
# 115  Sep2015        Indore                3147.367647
# 116  Sep2016        Indore                2958.968254
# 117  Sep2017        Indore                2805.190476
# 118  Sep2018        Indore                3169.380282
# 119  Sep2019        Indore                3684.897727
#
# [120 rows x 3 columns]

# %%
# nk['date']=pd.to_datetime(nk['date'])

# %%
io = nk[((nk.date >= 'Jan2017'))]

# %%
io.sort_values(by='date', inplace=True, ascending=True)
# Out:
# /home/akash/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
io
# Out:
#         date district_name  modal_price_(rs./quintal)
# 47   Jan2017        Indore                2867.000000
# 48   Jan2018        Indore                3165.082353
# 49   Jan2019        Indore                3439.389474
# 50   Jul2010        Indore                1828.094340
# 51   Jul2011        Indore                2157.770270
# ..       ...           ...                        ...
# 115  Sep2015        Indore                3147.367647
# 116  Sep2016        Indore                2958.968254
# 117  Sep2017        Indore                2805.190476
# 118  Sep2018        Indore                3169.380282
# 119  Sep2019        Indore                3684.897727
#
# [73 rows x 3 columns]

# %%
sns.set_style("dark", {"xtick.major.size": 8, "ytick.major.size": 8})

plt.figure(figsize=(15,5))
io['modal_price_(rs./quintal)'].plot()
# (df_new['Total Volume']/1000000).plot()
plt.legend()
plt.title('Total Volume vs Average Price during Atlantic Season , 2017')
# Out:
# Text(0.5, 1.0, 'Total Volume vs Average Price during Atlantic Season , 2017')
